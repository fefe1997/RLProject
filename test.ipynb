# %%
# !pip install procgen==0.10.4
# !wget https://raw.githubusercontent.com/fefe1997/RLProject/master/train/model.py
# !wget https://raw.githubusercontent.com/fefe1997/RLProject/master/train/policy.py
# !wget https://raw.githubusercontent.com/fefe1997/RLProject/master/train/utils.py
# Out:
# Requirement already satisfied: procgen==0.10.4 in /usr/local/lib/python3.6/dist-packages (0.10.4)
# Requirement already satisfied: filelock<4.0.0,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from procgen==0.10.4) (3.0.12)
# Requirement already satisfied: numpy<2.0.0,>=1.17.0 in /usr/local/lib/python3.6/dist-packages (from procgen==0.10.4) (1.19.4)
# Requirement already satisfied: gym3<1.0.0,>=0.3.3 in /usr/local/lib/python3.6/dist-packages (from procgen==0.10.4) (0.3.3)
# Requirement already satisfied: gym<1.0.0,>=0.15.0 in /usr/local/lib/python3.6/dist-packages (from procgen==0.10.4) (0.17.3)
# Requirement already satisfied: imageio<3.0.0,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen==0.10.4) (2.9.0)
# Requirement already satisfied: glfw<2.0.0,>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen==0.10.4) (1.12.0)
# Requirement already satisfied: moderngl<6.0.0,>=5.5.4 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen==0.10.4) (5.6.2)
# Requirement already satisfied: imageio-ffmpeg<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen==0.10.4) (0.3.0)
# Requirement already satisfied: cffi<2.0.0,>=1.13.0 in /usr/local/lib/python3.6/dist-packages (from gym3<1.0.0,>=0.3.3->procgen==0.10.4) (1.14.4)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen==0.10.4) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen==0.10.4) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym<1.0.0,>=0.15.0->procgen==0.10.4) (1.4.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from imageio<3.0.0,>=2.6.0->gym3<1.0.0,>=0.3.3->procgen==0.10.4) (7.0.0)
# Requirement already satisfied: glcontext<3,>=2 in /usr/local/lib/python3.6/dist-packages (from moderngl<6.0.0,>=5.5.4->gym3<1.0.0,>=0.3.3->procgen==0.10.4) (2.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi<2.0.0,>=1.13.0->gym3<1.0.0,>=0.3.3->procgen==0.10.4) (2.20)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym<1.0.0,>=0.15.0->procgen==0.10.4) (0.16.0)
# --2021-01-04 21:32:27--  https://raw.githubusercontent.com/fefe1997/RLProject/master/train/model.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2281 (2.2K) [text/plain]
# Saving to: ‘model.py.1’
#
# model.py.1          100%[===================>]   2.23K  --.-KB/s    in 0s
#
# 2021-01-04 21:32:27 (61.6 MB/s) - ‘model.py.1’ saved [2281/2281]
#
# --2021-01-04 21:32:28--  https://raw.githubusercontent.com/fefe1997/RLProject/master/train/policy.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1495 (1.5K) [text/plain]
# Saving to: ‘policy.py.1’
#
# policy.py.1         100%[===================>]   1.46K  --.-KB/s    in 0s
#
# 2021-01-04 21:32:28 (31.5 MB/s) - ‘policy.py.1’ saved [1495/1495]
#
# --2021-01-04 21:32:28--  https://raw.githubusercontent.com/fefe1997/RLProject/master/train/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15464 (15K) [text/plain]
# Saving to: ‘utils.py.1’
#
# utils.py.1          100%[===================>]  15.10K  --.-KB/s    in 0s
#
# 2021-01-04 21:32:28 (139 MB/s) - ‘utils.py.1’ saved [15464/15464]

# %% [markdown]
# Impala

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils import make_env, Storage, moving_average
from model import NatureDQN, Impala
from policy import Policy
import os

# Hyperparameters
total_steps = 8e6
num_envs = 32
num_levels = 10
num_steps = 256
num_epochs = 3
batch_size = 512
eps = .2
grad_eps = .5
value_coef = .5
entropy_coef = .01

# Define environment
# check the utils.py file for info on arguments
env = make_env(num_envs, num_levels=num_levels)
print('Observation space:', env.observation_space)
print('Action space:', env.action_space.n)

# Define network
in_channels = env.observation_space.shape[0]
feature_dim = 512
num_actions = env.action_space.n

model = os.getenv('MODEL', False)

# if model == 'NatureDQN':
encoder = Impala(in_channels, feature_dim)

#if model == 'Impala':
 # encoder = Impala(in_channels, feature_dim)


policy = Policy(encoder, feature_dim, num_actions)
policy.cuda()

# Define optimizer
# these are reasonable values but probably not optimal
optimizer = torch.optim.Adam(policy.parameters(), lr=5e-4, eps=1e-5)

# Define temporary storage
# we use this to collect transitions during each iteration
storage = Storage(
    env.observation_space.shape,
    num_steps,
    num_envs
)

# Run training
obs = env.reset()
step = 0
rewards, losses = [], []

while step < total_steps:

  # Use policy to collect data for num_steps steps
  policy.eval()
  for _ in range(num_steps):
    # Use policy
    action, log_prob, value = policy.act(obs)
    
    # Take step in environment
    next_obs, reward, done, info = env.step(action)

    # Store data
    storage.store(obs, action, reward, done, info, log_prob, value)
    
    # Update current observation
    obs = next_obs

  # Add the last observation to collected data
  _, _, value = policy.act(obs)
  storage.store_last(obs, value)

  # Compute return and advantage
  storage.compute_return_advantage()

  # Optimize policy
  policy.train()
  for epoch in range(num_epochs):

    # Iterate over batches of transitions
    generator = storage.get_generator(batch_size)
    for batch in generator:
      b_obs, b_action, b_log_prob, b_value, b_returns, b_advantage = batch

      # Get current policy outputs
      new_dist, new_value = policy(b_obs)
      new_log_prob = new_dist.log_prob(b_action)

      loss = policy.calculate_loss(b_log_prob, b_returns, b_advantage, new_log_prob, new_dist, new_value, eps, value_coef, entropy_coef)
      loss.mean().backward()

      # Clip gradients
      torch.nn.utils.clip_grad_norm_(policy.parameters(), grad_eps)

      # Update policy
      losses.append(loss.mean().item())
      optimizer.step()
      optimizer.zero_grad()

  # Update stats
  step += num_envs * num_steps
  print(f'Step: {step}\tMean reward: {storage.get_reward()}')
  rewards.append(storage.get_reward())

print('Completed training!')
torch.save(policy.state_dict(), 'checkpoint.pt')

# plot results

plt.figure(figsize=(16,6))
plt.subplot(211)
plt.plot(range(1, len(rewards)+1), moving_average(rewards), label='training reward')
plt.xlabel('episode'); plt.ylabel('reward')
plt.xlim((0, len(rewards)))
plt.legend(loc=4); plt.grid()
plt.subplot(212)
plt.plot(range(1, len(losses)+1), moving_average(losses), label='loss')
plt.xlabel('episode'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()
# Out:
# Observation space: Box(0.0, 1.0, (3, 64, 64), float32)
# Action space: 15
# Step: 8192	Mean reward: 3.9375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-ca5fb4aaecaf> in <module>()
#      69
#      70     # Take step in environment
# ---> 71     next_obs, reward, done, info = env.step(action)
#      72
#      73     # Store data
#
# /content/utils.py in step(self, actions)
#     255 		"""
#     256                 self.step_async(actions)
# --> 257                 return self.step_wait()
#     258
#     259         def render(self, mode='human'):
#
# /content/utils.py in step_wait(self)
#     528
#     529         def step_wait(self):
# --> 530                 obs, reward, done, info = self.venv.step_wait()
#     531                 return torch.Tensor(obs), reward, done, info
#     532
#
# /content/utils.py in step_wait(self)
#     510
#     511         def step_wait(self):
# --> 512                 obs, reward, done, info = self.venv.step_wait()
#     513                 return obs/255.0, reward, done, info
#     514
#
# /content/utils.py in step_wait(self)
#     495
#     496         def step_wait(self):
# --> 497                 obs, reward, done, info = self.venv.step_wait()
#     498                 return obs.transpose(0,3,1,2), reward, done, info
#     499
#
# /content/utils.py in step_wait(self)
#     463
#     464         def step_wait(self):
# --> 465                 obs, rews, news, infos = self.venv.step_wait()
#     466                 for i in range(len(infos)):
#     467                         infos[i]['reward'] = rews[i]
#
# /content/utils.py in step_wait(self)
#     336
#     337         def step_wait(self):
# --> 338                 obs, rews, dones, infos = self.venv.step_wait()
#     339                 return self.process(obs), rews, dones, infos
#     340
#
# /usr/local/lib/python3.6/dist-packages/gym3/interop.py in step_wait(self)
#     322     def step_wait(self):
#     323         rew, ob, first = self.env.observe()
# --> 324         return ob, rew, first, self.env.get_info()
#     325
#     326     def step(self, ac):
#
# /usr/local/lib/python3.6/dist-packages/gym3/libenv.py in get_info(self)
#     362
#     363     def get_info(self) -> List[Dict[str, Any]]:
# --> 364         self._c_lib.libenv_observe(self._c_env)
#     365         infos = [{} for _ in range(self.num)]
#     366         info = self._maybe_copy_dict(self._info)
#
# KeyboardInterrupt:

# %% [markdown]
# NatureDQN

# %%
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from utils import make_env, Storage, moving_average
from model import NatureDQN, Impala
from policy import Policy
import os

# Hyperparameters
total_steps = 8e6
num_envs = 32
num_levels = 10
num_steps = 256
num_epochs = 3
batch_size = 512
eps = .2
grad_eps = .5
value_coef = .5
entropy_coef = .01

# Define environment
# check the utils.py file for info on arguments
env = make_env(num_envs, num_levels=num_levels)
print('Observation space:', env.observation_space)
print('Action space:', env.action_space.n)

# Define network
in_channels = env.observation_space.shape[0]
feature_dim = 512
num_actions = env.action_space.n

model = os.getenv('MODEL', False)

# if model == 'NatureDQN':
encoder = NatureDQN(in_channels, feature_dim)

#if model == 'Impala':
 # encoder = Impala(in_channels, feature_dim)


policy = Policy(encoder, feature_dim, num_actions)
policy.cuda()

# Define optimizer
# these are reasonable values but probably not optimal
optimizer = torch.optim.Adam(policy.parameters(), lr=5e-4, eps=1e-5)

# Define temporary storage
# we use this to collect transitions during each iteration
storage = Storage(
    env.observation_space.shape,
    num_steps,
    num_envs
)

# Run training
obs = env.reset()
step = 0
rewards, losses = [], []

while step < total_steps:

  # Use policy to collect data for num_steps steps
  policy.eval()
  for _ in range(num_steps):
    # Use policy
    action, log_prob, value = policy.act(obs)
    
    # Take step in environment
    next_obs, reward, done, info = env.step(action)

    # Store data
    storage.store(obs, action, reward, done, info, log_prob, value)
    
    # Update current observation
    obs = next_obs

  # Add the last observation to collected data
  _, _, value = policy.act(obs)
  storage.store_last(obs, value)

  # Compute return and advantage
  storage.compute_return_advantage()

  # Optimize policy
  policy.train()
  for epoch in range(num_epochs):

    # Iterate over batches of transitions
    generator = storage.get_generator(batch_size)
    for batch in generator:
      b_obs, b_action, b_log_prob, b_value, b_returns, b_advantage = batch

      # Get current policy outputs
      new_dist, new_value = policy(b_obs)
      new_log_prob = new_dist.log_prob(b_action)

      loss = policy.calculate_loss(b_log_prob, b_returns, b_advantage, new_log_prob, new_dist, new_value, eps, value_coef, entropy_coef)
      loss.mean().backward()

      # Clip gradients
      torch.nn.utils.clip_grad_norm_(policy.parameters(), grad_eps)

      # Update policy
      losses.append(loss.mean().item())
      optimizer.step()
      optimizer.zero_grad()

  # Update stats
  step += num_envs * num_steps
  print(f'Step: {step}\tMean reward: {storage.get_reward()}')
  rewards.append(storage.get_reward())

print('Completed training!')
torch.save(policy.state_dict(), 'checkpoint.pt')

# plot results

plt.figure(figsize=(16,6))
plt.subplot(211)
plt.plot(range(1, len(rewards)+1), moving_average(rewards), label='training reward')
plt.xlabel('episode'); plt.ylabel('reward')
plt.xlim((0, len(rewards)))
plt.legend(loc=4); plt.grid()
plt.subplot(212)
plt.plot(range(1, len(losses)+1), moving_average(losses), label='loss')
plt.xlabel('episode'); plt.ylabel('loss')
plt.xlim((0, len(losses)))
plt.legend(loc=4); plt.grid()
plt.tight_layout(); plt.show()
# Out:
# Observation space: Box(0.0, 1.0, (3, 64, 64), float32)
# Action space: 15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-195d0a968892> in <module>()
#      69
#      70     # Take step in environment
# ---> 71     next_obs, reward, done, info = env.step(action)
#      72
#      73     # Store data
#
# /content/utils.py in step(self, actions)
#     255 		"""
#     256                 self.step_async(actions)
# --> 257                 return self.step_wait()
#     258
#     259         def render(self, mode='human'):
#
# /content/utils.py in step_wait(self)
#     528
#     529         def step_wait(self):
# --> 530                 obs, reward, done, info = self.venv.step_wait()
#     531                 return torch.Tensor(obs), reward, done, info
#     532
#
# /content/utils.py in step_wait(self)
#     510
#     511         def step_wait(self):
# --> 512                 obs, reward, done, info = self.venv.step_wait()
#     513                 return obs/255.0, reward, done, info
#     514
#
# /content/utils.py in step_wait(self)
#     495
#     496         def step_wait(self):
# --> 497                 obs, reward, done, info = self.venv.step_wait()
#     498                 return obs.transpose(0,3,1,2), reward, done, info
#     499
#
# /content/utils.py in step_wait(self)
#     463
#     464         def step_wait(self):
# --> 465                 obs, rews, news, infos = self.venv.step_wait()
#     466                 for i in range(len(infos)):
#     467                         infos[i]['reward'] = rews[i]
#
# /content/utils.py in step_wait(self)
#     336
#     337         def step_wait(self):
# --> 338                 obs, rews, dones, infos = self.venv.step_wait()
#     339                 return self.process(obs), rews, dones, infos
#     340
#
# /usr/local/lib/python3.6/dist-packages/gym3/interop.py in step_wait(self)
#     321
#     322     def step_wait(self):
# --> 323         rew, ob, first = self.env.observe()
#     324         return ob, rew, first, self.env.get_info()
#     325
#
# /usr/local/lib/python3.6/dist-packages/gym3/libenv.py in observe(self)
#     343
#     344     def observe(self) -> Tuple[np.ndarray, Dict[str, np.ndarray], np.ndarray]:
# --> 345         self._c_lib.libenv_observe(self._c_env)
#     346         return (
#     347             self._maybe_copy_ndarray(self._rew),
#
# KeyboardInterrupt:
